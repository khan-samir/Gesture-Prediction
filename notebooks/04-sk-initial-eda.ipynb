# %%
import pandas as pd
df = pd.read_csv('..\\data\\interim\\gesture-prediction-13-08-21-23-12-39.csv')
df.head()
# Out:
#    Unnamed: 0  time  channel1  channel2  channel3  channel4  channel5  \
# 0           0     1   0.00001  -0.00002  -0.00001  -0.00003   0.00000
# 1           1     5   0.00001  -0.00002  -0.00001  -0.00003   0.00000
# 2           2     6  -0.00001   0.00001   0.00002   0.00000   0.00001
# 3           3     7  -0.00001   0.00001   0.00002   0.00000   0.00001
# 4           4     8  -0.00001   0.00001   0.00002   0.00000   0.00001
#
#    channel6  channel7  channel8  class
# 0  -0.00001   0.00000  -0.00001    0.0
# 1  -0.00001   0.00000  -0.00001    0.0
# 2  -0.00002  -0.00001   0.00001    0.0
# 3  -0.00002  -0.00001   0.00001    0.0
# 4  -0.00002  -0.00001   0.00001    0.0
